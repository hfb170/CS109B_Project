# %% [markdown]
# # Data Acquisition Code
#
# <br>
# This code includes the necessary comand to acquire the data from the TMDB database based on the Python wrapper library of the TMDB API
#
#
# <br>
#
# ## A - Data Acquisition
#
#
# <br>

# %% [markdown]
# ### Importing Modules
#
#
# <br>

# %%
from pypandoc.pandoc_download import download_pandoc
import requests
import pypandoc
import json
import time
import itertools
import wget
import os
import png
import pickle
import numpy as np
import tmdbsimple as tmdb
import time
import sys
import urllib
from PIL import Image

import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from sklearn.cluster.bicluster import SpectralCoclustering
from sklearn.metrics import precision_recall_curve
import scipy

sns.set_style('white')
import pandas as pd

# %% [markdown]
# ### Importing ID File and Genres List
#
# <br>

# %%
# Importing Data file
idsdf = pd.read_csv('randomID2.csv').iloc[4000:8000]

# Importing Genres List
gen_list = pd.read_csv('genres_TMDB.csv')

# Printing a sample data
idsdf.head()
# Out:
#            imdb   tmdb
# 4000  tt1286809  16277
# 4001  tt0102351  11175
# 4002  tt0986233  10360
# 4003  tt1016307  25656
# 4004  tt0103016  10261

# %% [markdown]
# ### Acquiring from TMDB:
#
#
# <br>

# %% [markdown]
# #### 1- Specifying the IDs and length
#
#
# <br>

# %%
# Id Number
ids = idsdf.tmdb.values

# Length of Data
Len = len(ids)

# %% [markdown]
# #### 2- Requesting the data
#
# <br>
# The data to be collected is:
#
#  - Title
#  - Budget
#  - Overview
#  - Revenue
#  - Runtime
#  - Poster Path
#  - Genres
#  - Release Year
#  - Movie Poularity
#
#
# <br>

# %%
# Accessing the TMDB
tmdb.API_KEY = '95b208af4c92eb1ddd5c831f91c84e15'

# Initiate the data Lists
t_tmdb   = []    # title
b_tmdb   = []    # budget
o_tmdb   = []    # overview
rv_tmdb  = []    # revenue
rt_tmdb  = []    # runtime
p_tmdb   = []    # poster path
g_tmdb   = []    # Genres
y_tmdb   = []    # release year
pop_tmdb = []    # Popularity

# initiate counters
i = 0

for i in range(Len):
    
    # Specify the movie id
    movie = ids[i]
    
    # get the movie 
    mv = tmdb.Movies(movie)
    response = mv.info()
    
    # Append to the data based on availability of a poster
    if mv.poster_path:
        
        t_tmdb.append(mv.title.encode('utf-8' , 'strict'))
        b_tmdb.append(float(mv.budget))
        o_tmdb.append(mv.overview.encode('utf-8' , 'strict'))
        rv_tmdb.append(float(mv.revenue))
        rt_tmdb.append(float(mv.runtime))
        p_tmdb.append(mv.poster_path.encode('utf-8' , 'strict'))
        g_tmdb.append(mv.genres)
        y_tmdb.append(str(mv.release_date[:4]))
        pop_tmdb.append(float(mv.popularity))
        
    # Append an empty value otherwise        
    else:
        t_tmdb.append("")
        b_tmdb.append(0)
        o_tmdb.append("")
        rv_tmdb.append(0)
        rt_tmdb.append(0)
        p_tmdb.append("")
        g_tmdb.append("")
        y_tmdb.append("")
        pop_tmdb.append(0)
        
    
    # Pause
    time.sleep(1)
    
    
    
    # Update Results
    sys.stdout.flush()
    sys.stdout.write("\r Step: {}  id {}  acquired : {} ".format(i, movie , len(y_tmdb)))
# Out:
#  Step: 1999  id 28788  acquired : 2000

# %%
len(g_tmdb)
# Out:
# 2000

# %% [markdown]
# <br>
# ** In order to get information about the keywords and the director seperate code cells will be used since they belong o different sections of the database and requires a seperate call for each **
#
#
#
#
# <br>

# %% [markdown]
# <br>
# #### 3 - Getting the Keywords
#
# <br>

# %%
# Initiate the data Lists
k_tmdb   = []    # director


# initiate counters
i = 0

for i in range(Len):
    
    # Specify the movie id
    movie = ids[i]
    
    # get the movie 
    mv = tmdb.Movies(movie)
    response = mv.keywords()
    
    # get the keywords
    keywrds = mv.keywords
    
    # Check for availability
    if len(keywrds) > 0:
        
        # Extract the list
        k = []
    
        # iterrate for the length of the keywords
        for j in range (len(keywrds)):
        
            # Append to the list
            k.append(keywrds[j]['name'].encode('utf-8' , 'strict'))
    
        # Append to the data list
        k_tmdb.append(k)
        
    else:
        
        k_tmdb.append("")
    
    # Pause
    time.sleep(1)
    
    
    # Update Results
    sys.stdout.flush()
    sys.stdout.write("\r Step: {}  acquired : {} ".format(i, len(k_tmdb)))
# Out:
#  Step: 1999  acquired : 2000

# %% [markdown]
# <br>
# #### 3 - Director
#
# <br>

# %%
# Initiate the data Lists
d_tmdb   = []    # director



for i in range(Len):
    
    # Specify the movie id
    movie = ids[i]
    
    # get the movie 
    mv = tmdb.Movies(movie)
    response = mv.credits()
    
    # get the crew
    crew = mv.crew
    
    # Check for availability
    if len(crew) > 0:
        
        direc = ""
    
        # iterrate for the length of the keywords
        for j in range (len(crew)):
            
            # Search for director
            if crew[j]['job'] == "Director":
                
                direc = crew[j]['name'].encode('utf-8' , 'strict')
    
        # Append to the data list
        d_tmdb.append(direc)
        
    else:
        
        d_tmdb.append("")
    
    # Pause
    time.sleep(1)
    
    
    # Update Results
    sys.stdout.flush()
    sys.stdout.write("\r Step: {}  acquired : {} ".format(i, len(d_tmdb)))
# Out:
#  Step: 1999  acquired : 2000

# %% [markdown]
# <br>
# ### Constructing the features outpout Frame
#
# <br>
#
# In this section the data will be gathered in a single dataframe to be exported and shared
#
#
# <br>

# %%
# Aggregate the data in a data dictionary
data_dict = {'id' : ids , 'title' : t_tmdb , 'budget': b_tmdb , 'overview' : o_tmdb , 'revenue' : rv_tmdb , 
             'keywords' : k_tmdb , 'runtime' : rt_tmdb , 'poster_path' : p_tmdb , 'releaseyear' : y_tmdb , 
             'popularity' : pop_tmdb , 'director' : d_tmdb , 'genres' : g_tmdb }


# Make the data frame
data_raw = pd.DataFrame(data_dict)

# %%
data_raw.head(15)
# Out:
#         budget           director  \
# 0    2500000.0       Floyd Mutrux
# 1          0.0       Rudolph Maté
# 2   10000000.0         Dan Harris
# 3   22000000.0     David R. Ellis
# 4          0.0   Alfred L. Werker
# 5          0.0    Sidney J. Furie
# 6          0.0        Albert Pyun
# 7          0.0        Howard Hall
# 8          0.0         Mark Hicks
# 9       5000.0      Josh Bernhard
# 10    100000.0       Roger Corman
# 11    500000.0       Just Jaeckin
# 12         0.0  Penelope Spheeris
# 13         0.0
# 14  80000000.0          Rob Cohen
#
#                                                genres     id  \
# 0                   [{u'id': 35, u'name': u'Comedy'}]  21879
# 1   [{u'id': 18, u'name': u'Drama'}, {u'id': 80, u...  27399
# 2   [{u'id': 35, u'name': u'Comedy'}, {u'id': 18, ...  25350
# 3   [{u'id': 27, u'name': u'Horror'}, {u'id': 878,...  19116
# 4   [{u'id': 80, u'name': u'Crime'}, {u'id': 9648,...  17481
# 5   [{u'id': 18, u'name': u'Drama'}, {u'id': 28, u...  14149
# 6   [{u'id': 28, u'name': u'Action'}, {u'id': 12, ...  13945
# 7              [{u'id': 99, u'name': u'Documentary'}]  17700
# 8   [{u'id': 28, u'name': u'Action'}, {u'id': 35, ...  16287
# 9                    [{u'id': 18, u'name': u'Drama'}]  27806
# 10  [{u'id': 27, u'name': u'Horror'}, {u'id': 878,...  27623
# 11  [{u'id': 18, u'name': u'Drama'}, {u'id': 10749...  24402
# 12  [{u'id': 18, u'name': u'Drama'}, {u'id': 10402...  28054
# 13                [{u'id': 10402, u'name': u'Music'}]  17114
# 14  [{u'id': 28, u'name': u'Action'}, {u'id': 12, ...  11228
#
#                                              keywords  \
# 0                                        [teen movie]
# 1                                   [gangster, macao]
# 2                          [suicide, suicide mission]
# 3                                          [suspense]
# 4   [jewel, tower of london, chinchilla foot, play...
# 5
# 6   [prince, princess, sword fight, king, barbaria...
# 7   [octopus, sea turtle, imax, shrimp, manta ray,...
# 8
# 9   [date, blind date, woman between two men, pira...
# 10                                   [alien, b movie]
# 11  [female nudity, sex, nudity, bangkok, pubic ha...
# 12      [independent film, punk rock, woman director]
# 13
# 14  [taxi, new jersey, helicopter, river, hero, ta...
#
#                                              overview  popularity  \
# 0   Led by their comedic and pranking leader, Newb...    0.178502
# 1   Forbidden bears traces of several earlier film...    0.094302
# 2   Matt Travis is good-looking, popular, and his ...    0.231905
# 3   The teenager Madison McBride is traumatized by...    0.165075
# 4   Professor Moriarity has a scheme for stealing ...    0.586695
# 5   Four high school football stars enlist in the ...    0.034614
# 6   A mercenary with a three-bladed sword rediscov...    0.263891
# 7   Sea life in a whole new way. Deep Sea 3D, an u...    0.357550
# 8                                  No overview found.    0.000580
# 9   Nick (Mike Pantozzi) gets his girls the same w...    0.001179
# 10  An alien agent from the distant planet Davana ...    0.083809
# 11  Emmanuelle, a svelte, naive young woman, is en...    1.554986
# 12  When household tensions and a sense of worthle...    0.119411
# 13  By 1988, Rush had reached the pinnacle of thei...    0.002114
# 14  A group of armed robbers fleeing the police he...    0.969720
#
#                          poster_path releaseyear      revenue  runtime  \
# 0   /kZoeRbYSKYhFj5s15QCbHbydYTt.jpg        1980   10000000.0     91.0
# 1   /rNAqcCtBQO2UmvWx9DkRQGTwM8J.jpg        1953          0.0     85.0
# 2   /sR651HaKsdn0lg9LOs1BQGKSY4e.jpg        2004          0.0    111.0
# 3   /jAD5ltU8KNcmfurmNsaMox7n5Ab.jpg        2008          0.0     93.0
# 4   /6CMJC5FlagO9HM4YT5W3df9k5Nh.jpg        1939          0.0     85.0
# 5   /ggINMOcBPxoHZOehtPP3iRnxZRd.jpg        2008          0.0    118.0
# 6   /m0rAw4P71AyAGaMxCiaBdnz8hRA.jpg        1982          0.0    100.0
# 7   /2UglT7JjN6o7dYni4G16NYOFRJO.jpg        2006          0.0     41.0
# 8   /ezYuqtbdYNZEn4J1admwa6b9Gni.jpg        2009          0.0     88.0
# 9   /8G9pbb7pAC22OOXcPJETc2s6WJb.jpg        2009          0.0     66.0
# 10  /hHLkQjnKica7EHxW3mGozkBW296.jpg        1957          0.0     67.0
# 11  /d1MhpAVQkC2V6HOum69pBzSwvQu.jpg        1974          0.0     89.0
# 12  /7Lju6oLzkt003JOaxc1It0jUPja.jpg        1984          0.0     94.0
# 13  /9eQ59o1bicUdJpHraJhuZZmSsuF.jpg        1989          0.0     90.0
# 14  /cPl88Kh44fo005rYrdIxm62GQCb.jpg        1996  159212469.0    115.0
#
#                                 title
# 0               The Hollywood Knights
# 1                           Forbidden
# 2                    Imaginary Heroes
# 3                              Asylum
# 4   The Adventures of Sherlock Holmes
# 5                   The Four Horsemen
# 6          The Sword and the Sorcerer
# 7                         Deep Sea 3D
# 8                          Afro Ninja
# 9                       The Lionshare
# 10                  Not of This Earth
# 11                         Emmanuelle
# 12                           Suburbia
# 13              Rush: A Show of Hands
# 14                           Daylight

# %% [markdown]
# <br>
#
# ### Exporting the Data to csv Files
#
#
# <br>

# %%
# Genresdf.to_csv('Genres_labels_79.csv')
data_raw.to_csv('Meta_data_24.csv')

# %% [markdown]
# <br>
# ## END
